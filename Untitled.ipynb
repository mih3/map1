# %%
import pandas as pd
import requests
import logging
import time

logger = logging.getLogger("root")
logger.setLevel(logging.DEBUG)
# create console handler
ch = logging.StreamHandler()
ch.setLevel(logging.DEBUG)
logger.addHandler(ch)

# %%
# Google developer API key
from config import gkey

# %%
input_filename = "data.csv"

# %%
address_column_name = "ADDRESS"

# %%
data_df = pd.read_csv(input_filename, encoding='utf8')
data_df
# Out:
#       ID  YEAR       DATE                          NAME  \
# 0  10001  2019  4/15/2019  Solomon R. Guggenheim Museum
# 1  10002  2019   5/1/2019      The Museum of Modern Art
#
#                                  ADDRESS      CITY STATE  ZIPCODE COUNTRY  \
# 0       1071 5th Ave, New York, NY 10128  NEW YORK    NY    10128     USA
# 1  11 West 53 Street, New York, NY 10019  NEW YORK    NY    10019     USA
#
#    LATITUDE  LONGTITUDE  NARRATIVE
# 0       NaN         NaN        NaN
# 1       NaN         NaN        NaN

# %%
addresses = data_df[address_column_name].tolist()
addresses
# Out:
# ['1071 5th Ave, New York, NY 10128', '11 West 53 Street, New York, NY 10019']

# %%
import geopy
dir(geopy)
# Out:
# ['ArcGIS',
#  'AzureMaps',
#  'BANFrance',
#  'Baidu',
#  'Bing',
#  'DataBC',
#  'GeoNames',
#  'GeocodeEarth',
#  'GeocodeFarm',
#  'Geolake',
#  'GoogleV3',
#  'Here',
#  'IGNFrance',
#  'LiveAddress',
#  'Location',
#  'MapBox',
#  'Nominatim',
#  'OpenCage',
#  'OpenMapQuest',
#  'Pelias',
#  'Photon',
#  'PickPoint',
#  'Point',
#  'Timezone',
#  'TomTom',
#  'What3Words',
#  'Yandex',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  'compat',
#  'exc',
#  'format',
#  'geocoders',
#  'get_geocoder_for_service',
#  'location',
#  'point',
#  'timezone',
#  'units',
#  'util']

# %%
from geopy import geocoders
g = geocoders.GoogleV3(api_key='AIzaSyCrCjwtz4ILhQjxMWBLDCPBNkJU4Ys_2wc')

#create an input address string
#you can also build this by reading from an input database and building a string

inputAddress = addresses

#do the geocode
location = g.geocode(inputAddress, timeout=10)

# %%
from geopy import Nominatim

geolocator = Nominatim()

with open("addresses") as fp:
for line in fp:
    location = geolocator.geocode(line)
    print (location.latitude, location.longitude)
fp.close()
# Out:
#   File "<ipython-input-46-b11d02a087f7>", line 6
#     for line in fp:
#       ^
# IndentationError: expected an indented block

# %%
#some things you can get from the result
print(location.latitude, location.longitude)
#print(location.raw)
#print(location.address)
# Out:
# 40.7614327 -73.97762159999999

# %%
from geopy.geocoders import Nominatim

# %%
nom = Nominatim()
# Out:
# C:\Users\min\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Using Nominatim with the default "geopy/1.20.0" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
#   """Entry point for launching an IPython kernel.

# %%
nom.geocode("3995 23rd st, san francisco, ca 94114")
# Out:
# Location(3995, 23rd Street, Noe Valley, SF, California, 94114, USA, (37.7529648, -122.4317141, 0.0))

# %%
n=nom.geocode("3995 23rd st, san francisco, ca 94114")
n
# Out:
# Location(3995, 23rd Street, Noe Valley, SF, California, 94114, USA, (37.7529648, -122.4317141, 0.0))

# %%
n.latitude
# Out:
# 37.7529648

# %%
n.longitude
# Out:
# -122.4317141

# %%
type(n)
# Out:
# geopy.location.Location

# %%
data_df=pd.read_csv("data.csv")
data_df
# Out:
#       ID  Year       Date                          Name  \
# 0  10001  2019  4/11/2019  Solomon R. Guggenheim Museum
# 1  10002  2019  4/12/2019               DEVOCI?N COFFEE
#
#                                  Address      City State  Zipcode Country  \
# 0  1071 5th Ave, New York, NY 10128, USA  NEW YORK    NY    10128     USA
# 1   69 Grand St, Brooklyn, NY 11249, USA  NEW YORK    NY    11249     USA
#
#    Narrative
# 0        NaN
# 1        NaN

# %%
add_df=data_df["Address"]
add_df
# Out:
# 0    1071 5th Ave, New York, NY 10128, USA
# 1     69 Grand St, Brooklyn, NY 11249, USA
# Name: Address, dtype: object

# %%
data_df["Coordinates"]=data_df["Address"].apply(nom.geocode)
data_df
# Out:
#       ID  Year       Date                          Name  \
# 0  10001  2019  4/11/2019  Solomon R. Guggenheim Museum
# 1  10002  2019  4/12/2019               DEVOCI?N COFFEE
#
#                                  Address      City State  Zipcode Country  \
# 0  1071 5th Ave, New York, NY 10128, USA  NEW YORK    NY    10128     USA
# 1   69 Grand St, Brooklyn, NY 11249, USA  NEW YORK    NY    11249     USA
#
#    Narrative                                        Coordinates
# 0        NaN  (Guggenheim Museum, 1071, 5th Avenue, Manhatta...
# 1        NaN  (Devoción, 69, Grand Street, Williamsburg, BK,...

# %%
data_df["Coordinates"]
# Out:
# 0    (Guggenheim Museum, 1071, 5th Avenue, Manhatta...
# 1    (Devoción, 69, Grand Street, Williamsburg, BK,...
# Name: Coordinates, dtype: object

# %%
data_df.Coordinates[0]
# Out:
# Location(Guggenheim Museum, 1071, 5th Avenue, Manhattan Community Board 8, Manhattan, New York County, NYC, New York, 10128, USA, (40.78300035, -73.9589593986188, 0.0))

# %%
data_df.Coordinates[0].latitude
# Out:
# 40.78300035

# %%
data_df.Coordinates[0].longitude
# Out:
# -73.9589593986188

# %%
data_df.Coordinates[1]
# Out:
# Location(Devoción, 69, Grand Street, Williamsburg, BK, Kings County, NYC, New York, 11249, USA, (40.7159615, -73.9647675, 0.0))

# %%
data_df["Latitude"]=data_df["Coordinates"].apply(lambda x: x.latitude)
data_df["Longitude"]=data_df["Coordinates"].apply(lambda x: x.longitude)
data_df
# Out:
#       ID  Year       Date                          Name  \
# 0  10001  2019  4/11/2019  Solomon R. Guggenheim Museum
# 1  10002  2019  4/12/2019               DEVOCI?N COFFEE
#
#                                  Address      City State  Zipcode Country  \
# 0  1071 5th Ave, New York, NY 10128, USA  NEW YORK    NY    10128     USA
# 1   69 Grand St, Brooklyn, NY 11249, USA  NEW YORK    NY    11249     USA
#
#    Narrative                                        Coordinates   Latitude  \
# 0        NaN  (Guggenheim Museum, 1071, 5th Avenue, Manhatta...  40.783000
# 1        NaN  (Devoción, 69, Grand Street, Williamsburg, BK,...  40.715961
#
#    Longitude
# 0 -73.958959
# 1 -73.964767

# %%
data1_df=data_df.drop(columns=['City', 'State', 'Zipcode', 'Country', 'Narrative', 'Coordinates'])
data1_df
# Out:
#       ID  Year       Date                          Name  \
# 0  10001  2019  4/11/2019  Solomon R. Guggenheim Museum
# 1  10002  2019  4/12/2019               DEVOCI?N COFFEE
#
#                                  Address   Latitude  Longitude
# 0  1071 5th Ave, New York, NY 10128, USA  40.783000 -73.958959
# 1   69 Grand St, Brooklyn, NY 11249, USA  40.715961 -73.964767

# %%
data_df.to_json(r'C:\Users\min\Desktop\DEMO PROJECT\geo code\Export_DataFrame.json')

# %%
data1_df.to_json(r'C:\Users\min\Desktop\DEMO PROJECT\geo code\Export_DataFrame.json')

# %%
import pandas as pd
data2_df = pd.read_csv('data.csv',header=0,encoding = 'unicode_escape')
data2_df.head(5)
# Out:
#       ID  Year        Date                          Name  \
# 0  10001  2019   4/11/2019  Solomon R. Guggenheim Museum
# 1  10002  2019   4/12/2019               DEVOCI?N COFFEE
# 2  10003  2019   4/19/2019                 Gucci Wooster
# 3  10004  2017  11/24/2017              Gocheok Sky Dome
# 4  10005  2017  12/22/2017     Fukuoka Convention Center
#
#                                              Address      City State  \
# 0              1071 5th Ave, New York, NY 10128, USA  NEW YORK    NY
# 1               69 Grand St, Brooklyn, NY 11249, USA  NEW YORK    NY
# 2         63 Wooster Street, New York, NY 10012, USA  NEW YORK   NY
# 3  430, Gyeongin-ro, Gocheok-dong, Guro-gu, Seoul...     Seoul   NaN
# 4  2-1 Sekijomachi, Hakata Ward, Fukuoka, 812-003...   Fukuoka   NaN
#
#     Zipcode      Country  Narrative
# 0     10128          USA        NaN
# 1     11249          USA        NaN
# 2     10012          USA        NaN
# 3       NaN  South Korea        NaN
# ...

# %%
add2_df=data2_df["Address"]
add2_df
# Out:
# 0                 1071 5th Ave, New York, NY 10128, USA
# 1                  69 Grand St, Brooklyn, NY 11249, USA
# 2            63 Wooster Street, New York, NY 10012, USA
# 3     430, Gyeongin-ro, Gocheok-dong, Guro-gu, Seoul...
# 4     2-1 Sekijomachi, Hakata Ward, Fukuoka, 812-003...
# 5     8 Shintoshin, Chuo Ward, Saitama, 330-9111, Japan
# 6     No. 2, Section 4, Nanjing East Road, Songshan ...
# 7               550-0023 3-2-1 Chiyozaki Nishi-ku Osaka
# 8                      2 Stadium Walk, Singapore 397691
# 9     Popular 3 Rd, Ban Mai, Nonthaburi 11120, Thailand
# 10    J.W. Diokno Blvd, Pasay, 1300 Metro Manila, Ph...
# 11             1 Sky City Rd E, Chek Lap Kok, Hong Kong
# 12    L2-E-10, Enterprise 4, Technology Park Malaysi...
# 13    430, Gyeongin-ro, Gocheok-dong, Guro-gu, Seoul...
# 14    Estrada da Baia de Nossa Senhora da Esperanca,...
# Name: Address, dtype: object

# %%
data2_df["Coordinates"]=data2_df["Address"].apply(nom.geocode)
data2_df
# Out:
#        ID  Year        Date                          Name  \
# 0   10001  2019   4/11/2019  Solomon R. Guggenheim Museum
# 1   10002  2019   4/12/2019               DEVOCI?N COFFEE
# 2   10003  2019   4/19/2019                 Gucci Wooster
# 3   10004  2017  11/24/2017              Gocheok Sky Dome
# 4   10005  2017  12/22/2017     Fukuoka Convention Center
# 5   10006  2018   1/27/2018           Saitama Super Arena
# 6   10007  2018   2/10/2018                  Taipei Arena
# 7   10008  2018   2/23/2018            Kyocera Dome Osaka
# 8   10009  2018    3/3/2018      Singapore Indoor Stadium
# 9   10010  2018   3/16/2018     Impact, Muang Thong Thani
# 10  10011  2018   4/28/2018            Mall of Asia Arena
# 11  10012  2018    6/2/2018               AsiaWorld¨CExpo
# 12  10013  2018    6/7/2018                  Axiata Arena
# 13  10014  2018   7/13/2018              Gocheok Sky Dome
# 14  10015  2018   8/10/2018                   Cotai Arena
#
# ...

# %%
data2_df["Latitude"]=data2_df["Coordinates"].apply(lambda x: x.latitude if x != None else None)
data2_df["Longitude"]=data2_df["Coordinates"].apply(lambda x: x.longitude if x != None else None)
data2_df
# Out:
#        ID  Year        Date                          Name  \
# 0   10001  2019   4/11/2019  Solomon R. Guggenheim Museum
# 1   10002  2019   4/12/2019               DEVOCI?N COFFEE
# 2   10003  2019   4/19/2019                 Gucci Wooster
# 3   10004  2017  11/24/2017              Gocheok Sky Dome
# 4   10005  2017  12/22/2017     Fukuoka Convention Center
# 5   10006  2018   1/27/2018           Saitama Super Arena
# 6   10007  2018   2/10/2018                  Taipei Arena
# 7   10008  2018   2/23/2018            Kyocera Dome Osaka
# 8   10009  2018    3/3/2018      Singapore Indoor Stadium
# 9   10010  2018   3/16/2018     Impact, Muang Thong Thani
# 10  10011  2018   4/28/2018            Mall of Asia Arena
# 11  10012  2018    6/2/2018               AsiaWorld¨CExpo
# 12  10013  2018    6/7/2018                  Axiata Arena
# 13  10014  2018   7/13/2018              Gocheok Sky Dome
# 14  10015  2018   8/10/2018                   Cotai Arena
#
# ...
